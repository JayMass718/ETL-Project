# %%
from __future__ import print_function
import pandas as pd
from gspread_pandas import Spread, Client

# %%
nCoV_Jan27_9am = Spread('https://docs.google.com/spreadsheets/d/169AP3oaJZSMTquxtrkgFYMSp4gTApLTTWqo25qCpjL0/htmlview?usp=sharing&sle=true#',sheet=1)
nCoV_Jan26_11pm = Spread('https://docs.google.com/spreadsheets/d/169AP3oaJZSMTquxtrkgFYMSp4gTApLTTWqo25qCpjL0/htmlview?usp=sharing&sle=true#',sheet=2)
nCoV_Jan26_11am = Spread('https://docs.google.com/spreadsheets/d/169AP3oaJZSMTquxtrkgFYMSp4gTApLTTWqo25qCpjL0/htmlview?usp=sharing&sle=true#',sheet=3)
nCoV_Jan25_10pm = Spread('https://docs.google.com/spreadsheets/d/169AP3oaJZSMTquxtrkgFYMSp4gTApLTTWqo25qCpjL0/htmlview?usp=sharing&sle=true#',sheet=4)
nCoV_Jan25_12pm = Spread('https://docs.google.com/spreadsheets/d/169AP3oaJZSMTquxtrkgFYMSp4gTApLTTWqo25qCpjL0/htmlview?usp=sharing&sle=true#',sheet=5)
nCoV_Jan25_12am = Spread('https://docs.google.com/spreadsheets/d/169AP3oaJZSMTquxtrkgFYMSp4gTApLTTWqo25qCpjL0/htmlview?usp=sharing&sle=true#',sheet=6)
nCoV_Jan24_12pm = Spread('https://docs.google.com/spreadsheets/d/169AP3oaJZSMTquxtrkgFYMSp4gTApLTTWqo25qCpjL0/htmlview?usp=sharing&sle=true#',sheet=7)
nCoV_Jan24_12am = Spread('https://docs.google.com/spreadsheets/d/169AP3oaJZSMTquxtrkgFYMSp4gTApLTTWqo25qCpjL0/htmlview?usp=sharing&sle=true#',sheet=8)
nCoV_Jan23_12pm = Spread('https://docs.google.com/spreadsheets/d/169AP3oaJZSMTquxtrkgFYMSp4gTApLTTWqo25qCpjL0/htmlview?usp=sharing&sle=true#',sheet=9)
nCoV_Jan22_12pm = Spread('https://docs.google.com/spreadsheets/d/169AP3oaJZSMTquxtrkgFYMSp4gTApLTTWqo25qCpjL0/htmlview?usp=sharing&sle=true#',sheet=10)
nCoV_Jan22_12am = Spread('https://docs.google.com/spreadsheets/d/169AP3oaJZSMTquxtrkgFYMSp4gTApLTTWqo25qCpjL0/htmlview?usp=sharing&sle=true#',sheet=11)

# %%
print(nCoV_Jan27_9am)
# Out:
# <gspread_pandas.spread.Spread - 'User: 'julianmassiah718@gmail.com', Spread: 'Novel Coronavirus (2019-nCoV) Cases, provided by JHU CSSE old', Sheet: 'Jan27_9am''>

# %%
nCoV_Jan27_9am_df = nCoV_Jan27_9am.sheet_to_df()
nCoV_Jan26_11pm_df = nCoV_Jan26_11pm.sheet_to_df()
nCoV_Jan26_11am_df = nCoV_Jan26_11am.sheet_to_df()
nCoV_Jan25_10pm_df = nCoV_Jan25_10pm.sheet_to_df()
nCoV_Jan25_12pm_df = nCoV_Jan25_12pm.sheet_to_df()
nCoV_Jan25_12am_df = nCoV_Jan25_12am.sheet_to_df()
nCoV_Jan24_12pm_df = nCoV_Jan24_12pm.sheet_to_df()
nCoV_Jan24_12am_df = nCoV_Jan24_12am.sheet_to_df()
nCoV_Jan23_12pm_df = nCoV_Jan24_12am.sheet_to_df()
nCoV_Jan23_12pm_df = nCoV_Jan24_12am.sheet_to_df()
nCoV_Jan22_12pm_df = nCoV_Jan22_12pm.sheet_to_df()
nCoV_Jan22_12am_df = nCoV_Jan22_12am.sheet_to_df()

# %%
nCoV_Jan22_12pm_df = nCoV_Jan22_12pm_df.rename(columns={"Country": "Country/Region", "Date last updated": "Last Update"})

# %%
nCoV_Jan22_12am_df = nCoV_Jan22_12am_df.rename(columns={"Country": "Country/Region", "Date last updated": "Last Update"})

# %%
Total_columns = [nCoV_Jan27_9am_df, nCoV_Jan26_11pm_df,nCoV_Jan26_11am_df,nCoV_Jan25_10pm_df,nCoV_Jan25_12pm_df,nCoV_Jan25_12am_df,nCoV_Jan24_12pm_df,nCoV_Jan24_12am_df,nCoV_Jan23_12pm_df,nCoV_Jan23_12pm_df,nCoV_Jan22_12pm_df,nCoV_Jan22_12am_df]

Total_nCoV = pd.concat(Total_columns, sort=False)

Total_nCoV
# Out:
#                 Country/Region     Last Update Confirmed Deaths Recovered  \
# Province/State
# Hubei           Mainland China  1/27/2020 9:00      1423     76        45
# Guangdong       Mainland China  1/27/2020 9:00       151                3
# Zhejiang        Mainland China  1/27/2020 9:00       128                1
# Henan           Mainland China  1/27/2020 9:00       128
# Chongqing       Mainland China  1/27/2020 9:00       110      1
# ...                        ...             ...       ...    ...       ...
# Heilongjiang             China       1/21/2020              NaN       NaN
#                          Japan       1/21/2020         1    NaN       NaN
#                       Thailand       1/21/2020         2    NaN       NaN
#                    South Korea       1/21/2020         1    NaN       NaN
# Washington       United States       1/21/2020         1    NaN       NaN
#
#                Suspected
# Province/State
# Hubei                NaN
# ...

# %%
Total_nCoV = Total_nCoV.reset_index()

# %%
Total_nCoV = Total_nCoV.rename(columns={"Province/State": "State", "Country/Region": "Country" }) 
Total_nCoV
# Out:
#             State         Country     Last Update Confirmed Deaths Recovered  \
# 0           Hubei  Mainland China  1/27/2020 9:00      1423     76        45
# 1       Guangdong  Mainland China  1/27/2020 9:00       151                3
# 2        Zhejiang  Mainland China  1/27/2020 9:00       128                1
# 3           Henan  Mainland China  1/27/2020 9:00       128
# 4       Chongqing  Mainland China  1/27/2020 9:00       110      1
# ..            ...             ...             ...       ...    ...       ...
# 488  Heilongjiang           China       1/21/2020              NaN       NaN
# 489                         Japan       1/21/2020         1    NaN       NaN
# 490                      Thailand       1/21/2020         2    NaN       NaN
# 491                   South Korea       1/21/2020         1    NaN       NaN
# 492    Washington   United States       1/21/2020         1    NaN       NaN
#
#     Suspected
# 0         NaN
# 1         NaN
# 2         NaN
# ...

# %%
Sort_province = Total_nCoV.sort_values(by=['State'],ascending=False)
Sort_province
# Out:
#         State         Country         Last Update Confirmed Deaths Recovered  \
# 462  Zhejiang           China     1/22/2020 12:00        10    NaN       NaN
# 480  Zhejiang           China           1/21/2020         5    NaN       NaN
# 316  Zhejiang  Mainland China  1/24/2020 12:00 AM        43                1
# 392  Zhejiang  Mainland China  1/24/2020 12:00 AM        43                1
# 50   Zhejiang  Mainland China     1/26/2020 23:00       128                1
# ..        ...             ...                 ...       ...    ...       ...
# 134                 Singapore  1/26/2020 11:00 AM         4
# 133               South Korea  1/26/2020 11:00 AM         3
# 132                  Thailand  1/26/2020 11:00 AM         8                2
# 131                     Japan  1/26/2020 11:00 AM         4                1
# 91                  Australia     1/26/2020 23:00         4
#
#     Suspected
# 462
# 480        16
# 316
# 392
# 50
# ..        ...
# 134
# 133
# 132
# 131
# ...

# %%
province_list =Sort_province.State.unique()
province_list
# Out:
# array(['Zhejiang', 'Yunnan', 'Xinjiang', 'Washington', 'Tibet', 'Tianjin',
#        'Taiwan', 'Sichuan', 'Shanxi', 'Shanghai', 'Shandong', 'Shaanxi',
#        'Qinghai', 'Ontario', 'Ningxia', 'Macau', 'Liaoning', 'Jilin',
#        'Jiangxi', 'Jiangsu', 'Inner Mongolia', 'Illinois', 'Hunan',
#        'Hubei', 'Hong Kong', 'Henan', 'Heilongjiang', 'Hebei', 'Hainan',
#        'Guizhou', 'Guangxi', 'Guangdong', 'Gansu', 'Fujian', 'Chongqing',
#        'Chicago', 'California', 'Beijing', 'Arizona', 'Anhui', ''],
#       dtype=object)

# %%
province_dfs=[]

for province in province_list:
    province_dfs.append(Sort_province[Sort_province['State']== province].sort_values(by=['Last Update'],axis=0,ascending=False).copy())

# %% [markdown]
# ### Load to SQL

# %%
from sqlalchemy import create_engine

# %%
connection_string = "postgres:postgres@localhost:5432/nCoV_db"

# %%
engine=create_engine(f"postgresql://{connection_string}")

# %%
province_list[-1] = "Other"
fixed_cols = [column.lower().replace(" ","_") for column in province_dfs[0].columns]

# %%
for virus_df,province_name in zip(province_dfs,province_list):
    virus_df.columns = fixed_cols
    virus_df.to_sql(name=province_name.lower().replace(" ","_"),con=engine,if_exists="replace",index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2274         try:
# -> 2275             return fn()
#    2276         except dialect.dbapi.Error as e:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in connect(self)
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     759         if not fairy:
# --> 760             fairy = _ConnectionRecord.checkout(pool)
#     761
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
# ...
